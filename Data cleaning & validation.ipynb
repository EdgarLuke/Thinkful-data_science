# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import re

# %%
# Read in the data as a pandas DataFrame, with encoding attribute set to properly read in the data
df = pd.read_csv('WELLCOME_APCspend2013_forThinkful.csv', encoding='latin-1')

df.head(10) # Viewing top of dataframe to get a sense of row/column info
# Out:
#               PMID/PMCID                                     Publisher  \
# 0                    NaN                                           CUP
# 1             PMC3679557                                           ACS
# 2  23043264  PMC3506128                                            ACS
# 3    23438330 PMC3646402                                           ACS
# 4   23438216 PMC3601604                                            ACS
# 5             PMC3579457                                           ACS
# 6             PMC3709265                                           ACS
# 7   23057412 PMC3495574                                            ACS
# 8      PMCID: PMC3780468  ACS (Amercian Chemical Society) Publications
# 9      PMCID: PMC3621575  ACS (Amercian Chemical Society) Publications
#
#                     Journal title  \
# 0          Psychological Medicine
# 1               Biomacromolecules
# 2                      J Med Chem
# 3                      J Med Chem
# 4                      J Org Chem
# 5  Journal of Medicinal Chemistry
# 6    Journal of Proteome Research
# 7                       Mol Pharm
# 8            ACS Chemical Biology
# 9            ACS Chemical Biology
#
#                                        Article title  \
# 0  Reduced parahippocampal cortical thickness in ...
# 1  Structural characterization of a Model Gram-ne...
# 2  Fumaroylamino-4,5-epoxymorphinans and related ...
# 3  Orvinols with mixed kappa/mu opioid receptor a...
# 4  Regioselective opening of myo-inositol orthoes...
# 5  Comparative Structural and Functional Studies ...
# 6  Mapping Proteolytic Processing in the Secretom...
# 7  Quantitative silencing of EGFP reporter gene b...
# 8  A Novel Allosteric Inhibitor of the Uridine Di...
# 9  Chemical proteomic analysis reveals the drugab...
#
#   COST (£) charged to Wellcome (inc VAT when charged)
# 0                                              £0.00
# 1                                           £2381.04
# 2                                            £642.56
# 3                                            £669.64
# 4                                            £685.88
# 5                                           £2392.20
# 6                                           £2367.95
# 7                                            £649.33
# 8                                           £1294.59
# 9                                           £1294.78

# %% [markdown]
# ### My first question to answer is: What are the 5 most common journals and the total articles for each?

# %%
# To get a better count for our journal titles, convert all to lower case to remove any Capitalization differences that might throw off our counts
df['Journal title'] = df['Journal title'].str.lower()

# Find the Top 5 Journals based on number of articles in the dataset
df['Journal title'].value_counts().head(5)
# Out:
# plos one                           190
# journal of biological chemistry     53
# neuroimage                          29
# plos genetics                       24
# plos pathogens                      24
# Name: Journal title, dtype: int64

# %%
# To ensure these counts are as accurate as possible, let's try and get rid of any duplicate or missing 
# articles that appear in the data.
# I'll start by extracting the PMCID and PMID data to find any matching id's and remove them from the set

# Creating a function that obtains the 7-digit id that starts with 3 from the alphanumeric id which is the PMCID
def get_pmcid(x):
    pmcid = re.findall('3\d{6}', str(x))
    if len(pmcid) > 0:
        return pmcid[- 1]

# Next function obtains the 8-digit id that starts with 2 from the alphanumeric id col, which is the PMID
def get_pmid(x):
    pmid = re.findall('2\d{7}', str(x))
    if len(pmid) > 0:
        return pmid[0]

# Applying our functions to the PMID/PMCID col, and creating two new cols
df['PMID'] = df['PMID/PMCID'].apply(get_pmid)
df['PMCID'] = df['PMID/PMCID'].apply(get_pmcid)

# Now dropping the old column
del df['PMID/PMCID']

# With our new columns in place, we can drop any duplicate ids that exist:
df.drop_duplicates(subset='PMID', keep="last", inplace=True)
df.drop_duplicates(subset='PMCID', keep="last", inplace=True)

# Dropping rows with no IDs
df.drop(df[(df.PMID == None) & (df.PMCID == None)].index, inplace=True)

# %%
# After cleaning, let's check our article counts per journal
df['Journal title'].value_counts().head(5)
# Out:
# plos one                           23
# journal of general virology         8
# journal of biological chemistry     7
# elsevier                            7
# plos pathogens                      5
# Name: Journal title, dtype: int64

# %% [markdown]
# ### To our 2nd question: What are the mean, median, and standard deviation for the cost of an article per Journal?

# %%
# Immediately notice complicated column title for COST, let's simplify
df['cost'] = df['COST (£) charged to Wellcome (inc VAT when charged)']

# %%
# Deleting the old column
del df['COST (£) charged to Wellcome (inc VAT when charged)']

# %%
# There are some unnecessary currency symbols in the 'cost' column data, clean for later statistical analysis and manipulation
df['cost'] = df.cost.str.replace('£', '')
df['cost'] = df.cost.str.replace('$', '')

df.head()
# Out:
#                                 Publisher          Journal title  \
# 2                                     ACS             j med chem
# 3                                     ACS             j med chem
# 4                                     ACS             j org chem
# 7                                     ACS              mol pharm
# 18  American Association of Immunologists  journal of immunology
#
#                                         Article title      PMID    PMCID  \
# 2   Fumaroylamino-4,5-epoxymorphinans and related ...  23043264  3506128
# 3   Orvinols with mixed kappa/mu opioid receptor a...  23438330  3646402
# 4   Regioselective opening of myo-inositol orthoes...  23438216  3601604
# 7   Quantitative silencing of EGFP reporter gene b...  23057412  3495574
# 18  Regulation of Foxp3+ Inducible Regulatory T Ce...  23455506  3607399
#
#        cost
# 2    642.56
# 3    669.64
# 4    685.88
# 7    649.33
# 18  3108.08

# %%
# Checking datatype of cost column, may require reformatting
df.cost.dtype
# Out:
# dtype('O')

# %%
# Convert data to proper format for statistical analysis
df['cost'] = df['cost'].astype('float64')

# %%
# Want to get rid of any empty cost values
df.dropna(subset=['cost'], inplace=True)

df.head(10)
# Out:
#                                 Publisher                    Journal title  \
# 2                                     ACS                       j med chem
# 3                                     ACS                       j med chem
# 4                                     ACS                       j org chem
# 7                                     ACS                        mol pharm
# 18  American Association of Immunologists            journal of immunology
# 19              American Chemical Society             acs chemical biology
# 24              American Chemical Society        american chemical society
# 25              American Chemical Society             analytical chemistry
# 28              American Chemical Society           bioconjugate chemistry
# 31              American Chemical Society  journal of medicinal chemistry
#
#                                         Article title      PMID    PMCID  \
# 2   Fumaroylamino-4,5-epoxymorphinans and related ...  23043264  3506128
# 3   Orvinols with mixed kappa/mu opioid receptor a...  23438330  3646402
# 4   Regioselective opening of myo-inositol orthoes...  23438216  3601604
# 7   Quantitative silencing of EGFP reporter gene b...  23057412  3495574
# 18  Regulation of Foxp3+ Inducible Regulatory T Ce...  23455506  3607399
# 19  Discovery of an allosteric inhibitor binding s...  24015914  3833349
# 24  Characterizing the Fatty Acid Binding Site in ...  22971149  3466778
# 25  Amphipathic polymers facilitate the study of f...  23072351  3072351
# 28  Design, synthesis and functional activity of l...  23458425  3630740
# 31  A class of 5-nitro-2-furancarboxylamides with ...  23281892  3579312
#
#        cost
# 2    642.56
# 3    669.64
# 4    685.88
# 7    649.33
# 18  3108.08
# 19  1267.76
# 24  1533.29
# 25  2082.74
# 28  1565.26
# 31   321.12

# %%
# remove NA values or any obviously wrong price:
df.cost.fillna(0, inplace=True)
df.drop(df[(df.cost > 10000.00)].index, inplace=True)

# %%
# With a cleaned 'cost' col, let's answer our second question by getting the mean, median, and std.deviation for each journal
df.groupby('Journal title').cost.describe().sort_values(by='count', ascending=False)
# Out:
#                                                   count         mean  \
# Journal title
# plos one                                           22.0  1056.374091
# journal of general virology                         8.0  2034.375000
# journal of biological chemistry                     7.0  1654.457143
# elsevier                                            7.0  2625.421429
# plos pathogens                                      5.0  1560.492000
# nucleic acids research                              5.0  1629.600000
# journal of neuroscience                             4.0  1751.795000
# chembiochem                                         4.0  2034.242500
# neuroimage                                          4.0  2192.320000
# journal of virology                                 4.0  1488.165000
# journal of clinical endocrinology and metabolism    4.0  2136.607500
# molecular microbiology                              4.0  2088.932500
# british journal of pharmacology                     4.0  2134.847500
# proceedings of the national academy of sciences     4.0   740.355000
# molecular immunology                                3.0  2297.373333
# plos                                                3.0  1043.666667
# biological psychiatry                               3.0  2409.750000
# psychopharmacology                                  3.0  1827.906667
# plos genetics                                       3.0  1759.763333
# behavioral neuroscience                             3.0  3147.706667
# oncogene                                            3.0  3164.816667
# cell cycle                                          3.0   746.990000
# febs journal                                        3.0  2088.303333
# angewandte chemie international edition             3.0  2437.190000
# journal of infectious diseases                      3.0  2305.200000
# human molecular genetics                            3.0  2100.000000
# hepatology                                          3.0  1628.100000
# experimental parasitology                           2.0  2385.360000
# journal of leukocyte biology                        2.0  1777.190000
# chemmedchem                                         2.0  1990.470000
# ...                                                 ...          ...
# journal of biological physics                       1.0  2226.160000
# human mol genetics online                           1.0  2040.000000
# health psychology                                   1.0  3188.300000
# health and place                                    1.0  1749.740000
# european journal of medical genetics                1.0  2468.500000
# development                                         1.0  2400.000000
# development science                                 1.0  2351.810000
# developmental cell                                  1.0  3845.380000
# diabetic medicine                                   1.0  2377.660000
# embo                                                1.0  3120.000000
# epilepsia                                           1.0  1834.770000
# essays in biochemistry                              1.0   270.000000
# eur j immunol                                       1.0  1834.770000
# european child and adolescent psychiatty            1.0  2285.920000
# european journal of endocrinology                   1.0  1200.000000
# european journal of human genetics                  1.0  2400.000000
# european journal of public health                   1.0  1800.000000
# haematologica/the haematology journal               1.0   378.700000
# experimental brain research                         1.0  1889.100000
# experimental hematology                             1.0  2328.240000
# expert reviews in anti-infective chemotherapy       1.0  1700.000000
# fems microbiology letters                           1.0  2008.840000
# frontiers in human neuroscience                     1.0  1000.870000
# frontiers in immunology                             1.0  1014.440000
# frontiers in t cell biology                         1.0  1017.580000
# future medicinal chemistry                          1.0  2040.000000
# genesis: journal of genetics                        1.0  2376.400000
# genome biology                                      1.0  1788.900000
# gut                                                 1.0  2340.000000
# virus research                                      1.0  1947.090000
#
#                                                          std      min  \
# Journal title
# plos one                                          252.506052   747.05
# journal of general virology                       185.615530  1575.00
# journal of biological chemistry                   565.026036  1119.61
# elsevier                                          964.947531  2152.76
# plos pathogens                                    178.054111  1397.00
# nucleic acids research                            481.826525   852.00
# journal of neuroscience                           343.061020  1283.00
# chembiochem                                       129.568271  1851.15
# neuroimage                                        292.179787  1758.89
# journal of virology                               161.063270  1247.41
# diabetic medicine                                 2377.6600  2377.66
# embo                                              3120.0000  3120.00
# epilepsia                                         1834.7700  1834.77
# essays in biochemistry                             270.0000   270.00
# eur j immunol                                     1834.7700  1834.77
# european child and adolescent psychiatty          2285.9200  2285.92
# european journal of endocrinology                 1200.0000  1200.00
# european journal of human genetics                2400.0000  2400.00
# european journal of public health                 1800.0000  1800.00
# haematologica/the haematology journal              378.7000   378.70
# experimental brain research                       1889.1000  1889.10
# experimental hematology                           2328.2400  2328.24
# expert reviews in anti-infective chemotherapy     1700.0000  1700.00
# fems microbiology letters                         2008.8400  2008.84
# frontiers in human neuroscience                   1000.8700  1000.87
# frontiers in immunology                           1014.4400  1014.44
# frontiers in t cell biology                       1017.5800  1017.58
# future medicinal chemistry                        2040.0000  2040.00
# genesis: journal of genetics                      2376.4000  2376.40
# genome biology                                    1788.9000  1788.90
# gut                                               2340.0000  2340.00
# virus research                                    1947.0900  1947.09
#
# [266 rows x 8 columns]

# %% [markdown]
# ### Final challenge question: What are the costs paid by subject area?

# %%
# For the challenge, I'll assume getting the cost paid by subject area can be reflected by each 'Journal title'
# and summing the cost for the articles associated with each. 
df.groupby('Journal title').sum().sort_values(by='cost', ascending=False)
# Out:
#                                                         cost
# Journal title
# plos one                                            23240.23
# elsevier                                            18377.95
# journal of general virology                         16275.00
# journal of biological chemistry                     11581.20
# oncogene                                             9494.45
# behavioral neuroscience                              9443.12
# neuroimage                                           8769.28
# journal of clinical endocrinology and metabolism     8546.43
# british journal of pharmacology                      8539.39
# molecular microbiology                               8355.73
# nucleic acids research                               8148.00
# chembiochem                                          8136.97
# plos pathogens                                       7802.46
# angewandte chemie international edition              7311.57
# biological psychiatry                                7229.25
# nature communications                                7140.00
# current biology                                      7043.60
# journal of neuroscience                              7007.18
# journal of infectious diseases                       6915.60
# molecular immunology                                 6892.12
# human molecular genetics                             6300.00
# febs journal                                         6264.91
# cell reports                                         6254.02
# embo reports                                         6240.00
# journal of virology                                  5952.66
# the lancet neurology                                 5760.00
# psychopharmacology                                   5483.72
# plos genetics                                        5279.29
# journal of immunology                                5040.77
# journal of investigative dermatology                 5040.00
# ...                                                      ...
# acs chemical biology                                 1267.76
# european journal of endocrinology                    1200.00
# springer science + business media                    1117.37
# sci rep                                              1068.00
# journal of biol chem                                 1055.07
# biinformatics                                        1047.00
# frontiers in t cell biology                          1017.58
# public library of science                            1016.24
# frontiers in immunology                              1014.44
# frontiers in human neuroscience                      1000.87
# rna biology                                           975.41
# database                                              960.00
# proceedings of the national academy of sciences...    890.00
# international journal of health geographics           867.38
# cancer research                                       799.44
# statistics in medicine                                791.19
# acta crystallography d                                774.19
# j immunol                                             772.13
# acs nano                                              693.39
# j org chem                                            685.88
# biophysical journal                                   671.04
# mol pharm                                             649.33
# international journal of rheumatology                 626.00
# journal of parasitology research                      623.95
# autophagy                                             601.10
# journal of visualized experiements                    517.50
# haematologica/the haematology journal                 378.70
# plos biology                                          343.51
# journal of medicinal chemistry                        321.12
# essays in biochemistry                                270.00
#
# [266 rows x 1 columns]

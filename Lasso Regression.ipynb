# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
import math
import seaborn as sns
import sklearn
from sklearn import linear_model
from sklearn import preprocessing
# %matplotlib inline
sns.set_style('white')

# %% [markdown]
# Ridge regression shrinks parameter estimates, but the estimates never reach exactly 0.  **LASSO** (Least Absolute Shrinkage and Selection Operator), on the other hand, is a model optimization mechanic that works by trying to force small parameter estimates to be equal to zero, effectively dropping them from the model.  This can prevent overfitting, and also works as an embedded feature selection method.  Lasso is extremely handy when you are dealing with thousands or hundreds of thousands of predictors and need to optimize processor time, or when you want to arrive at a simpler solution that is easier to interpret.
#
# The cost function to minimize for lasso is _very similar_ to the cost function minimized for ridge. Can you spot the difference?
#
# $$\sum_{i=1}^n(y_i-(\alpha+\beta x_i))^2+\lambda\sum_{j=1}^p|\beta_j| $$
#
# The difference is that rather than penalizing by the sum of *squared* coefficients as ridge does, lasso penalizes by the sum of the *absolute values* of the coefficients.  This means the penalty doesn't increase as swiftly with coefficient size.  Regularization based on the sum of the absolute weights is also called "**L1 regularization**".
#
# Why would penalizing with the sum of the absolute values of coefficients lead to a solution with zero estimates for some parameters, while penalizing with the sum of the squares of coefficients does not?  It all comes down to derivatives.
#
# We encountered derivatives briefly during an earlier assignment on the gradient descent algorithm.  You may recall that a partial derivative represents the sensitivity of one quantity to changes in another quantity.  In the case of both ordinary least squares regression and ridge regression, the derivative used to find the optimal solution is the partial derivative of the cost function relative to the coefficients in $\beta$:
#
# $$\frac{\partial}{\partial\beta}$$
#
# Unfortunately, that won't work for lasso. While we can calculate a derivative for most of the values of $x$ in lasso, there is no derivative where $x=0$.  You can imagine this as our multi-dimensional surface made up of gradients having a big hole in it (the technical term for the hole is a "*discontinuity*"). If the gradient descent algorithm calculates a value that falls in the "hole", it has no idea where to go next.  The model "fails to converge". In other words, it fails to arrive at an optimal solution.

# %% [markdown]
# # Fitting Lasso: Coordinate Descent Algorithm
#
# Since basing modeling strategy on a surface with a hole in it is obviously not ideal, lasso regression models are optimized using a coordinate descent algorithm rather than a gradient descent algorithm.  Coordinate descent works like this:
#
# Pick some starting values for $\beta$, often $\beta=0$.
#
# For each feature $j$ in $\beta$:
# * Predict the outcome using all features except for $j$.
# * Look at how the residuals from the model using $\beta_{-j}$ (all betas except $j$) correlate with feature $j$. This correlation is called $\rho_j$.
# * If the correlation falls within an area enclosing 0 defined by $\lambda$, set $\beta_j=0$. (called *soft threshholding*)
# * If $\rho_j < \frac{\lambda}2$ set $\beta_j$ equal to $\rho_j + \frac{\lambda}2$
# * If $\rho_j > \frac{\lambda}2$ set $\beta_j$ equal to $\rho_j - \frac{\lambda}2$
#
# This will iterate through all features 1 through $j$ on each cycle, then begin again.  Alternatively, the algorithm can be set to choose to exclude a feature at random each iteration, rather than cycling through all features.  Each time a feature is checked, it will shrink a bit from the previous time (unless the feature is already set to 0, in which case it will remain 0).
#
# Continue until the maximum difference between parameter estimates in the previous cycle and the current cycle is less than a pre-determined threshold $tol$.  For SKlearn, $tol$ defaults to 0.0001.
#
# To summarize: Lasso works by iteratively fitting a model to the data while excluding one of the features.  It then checks how well the model reproduces the data, and if the model fit is good enough (with "good enough" determined by $\lambda$) then the excluded feature is deemed unnecessary and its $\beta$ is set to zero, effectively excluding it from the model. Otherwise, the excluded feature's $\beta$ is set using a combination of the correlation of the feature with the model residuals ($\rho_j$) and $\frac{\lambda}2$ and a new iteration begins, using the newly-computed $\beta$ for the previously-excluded feature and excluding a new feature.  This continues until the change in $\beta$ is less than a pre-determined threshold.
#
# Hopefully this demonstrates how lasso can both create overfitting-protection through shrinkage and create sparsity (many parameters set to 0) through feature selection.  Let's see it at work, using the same dataset as previously.

# %%
# Load the data again. Keep air quality data, drop the index column
# and any missing data columns.
df = pd.read_csv('Default.csv').iloc[:,1:].dropna()

# Recode strings to numeric.
df['default'] = np.where(df['default']=='Yes', 1, 0)
df['student'] = np.where(df['student']=='Yes', 1, 0)
names = df.columns
df = pd.DataFrame(preprocessing.scale(df), columns=names)

# Define the training and test sizes.
trainsize = int(df.shape[0] / 2)
df_test = df.iloc[trainsize:, :].copy()
df_train = df.iloc[:trainsize, :].copy()

Y_train = df_train['income'].values.reshape(-1, 1)
X_train = df_train.loc[:, ~(df_train.columns).isin(['income'])]

# Make some new features to capture potential quadratic and cubic
# relationships between solar radiation and day or temperature.
df_train['balance_student'] = df_train['balance'] * df_train['student']
df_train['balance_default'] = df_train['balance'] * df_train['default']
df_train['student_default'] = df_train['student'] * df_train['default']
df_train['balance_sqrt'] = (df_train['balance'] + 100) ** .5
df_train['balance2'] = (df_train['balance'] + 100) ** 2
df_train['balance3'] = (df_train['balance'] + 100) ** 3

X_train2 = df_train.loc[:, ~(df_train.columns).isin(['income'])]

# Test the simpler model with smaller coefficients.
Y_test = df_test['income'].values.reshape(-1, 1)
X_test = df_test.loc[:, ~(df_test.columns).isin(['income'])]

# Test the more complex model with larger coefficients.
df_test['balance_student'] = df_test['balance'] * df_test['student']
df_test['balance_default'] = df_test['balance'] * df_test['default']
df_test['student_default'] = df_test['student'] * df_test['default']
df_test['balance_sqrt'] = (df_test['balance'] + 100) ** .5
df_test['balance2'] = (df_test['balance'] + 100) ** 2
df_test['balance3'] = (df_test['balance'] + 100) ** 3
X_test2 = df_test.loc[:, ~(df_test.columns).isin(['income'])]

# %%
# Small number of parameters
lass = linear_model.Lasso(alpha=.35)
lassfit = lass.fit(X_train, Y_train)
print('R^2 for the model with few features:')
print(lass.score(X_train, Y_train))
origparams = np.append(lassfit.coef_, lassfit.intercept_)
print('\nParameter estimates for the model with few features:')
print(origparams)

lassBig = linear_model.Lasso(alpha=.35)
lassBig.fit(X_train2, Y_train)
print('\nR^2 for the model with many features:')
print(lassBig.score(X_train2, Y_train))
origparams = np.append(lassBig.coef_, lassBig.intercept_)
print('\nParamtere estimates for the model with many features:')
print(origparams)
# Out:
# R^2 for the model with few features:
# 0.450062579301185
#
# Parameter estimates for the model with few features:
# [-0.         -0.40657726 -0.          0.00114596]
#
# R^2 for the model with many features:
# 0.44363376712897096
#
# Paramtere estimates for the model with many features:
# [ 0.00000000e+00 -3.89351238e-01  0.00000000e+00 -0.00000000e+00
#   0.00000000e+00 -0.00000000e+00  0.00000000e+00 -2.77688887e-04
#  -7.09158792e-07  3.48711577e+00]

# %% [markdown]
# Checking predictive power using the test set:

# %%
print(lass.score(X_test, Y_test))

print(lassBig.score(X_test2, Y_test))
# Out:
# 0.44553225151184195
# 0.4380466345914476

# %% [markdown]
# ## Regularization parameter: Lasso
#
# The $\lambda$ for lasso can var between 0 (no penalty, acts like OLS) and infinity.  If $\lambda$ is too large, all parameters will be set to zero.
#
# Create a plot below of how $R^2$ varies across different values of $\lambda$ for ridge and lasso regression. Use logic and code similar to the ridge regression demonstration above, and base your plot on the X_train2 feature set.
#
# Do lasso and ridge yield the same $R^2$ for a given lambda value?
#
# Submit your work and discuss the results with your mentor.

# %%
# Fitting a ridge regression model. Alpha is the regularization
# parameter (usually called lambda). As alpha gets larger, parameter
# shrinkage grows more pronounced. Note that by convention, the
# intercept is not regularized. Since we standardized the data
# earlier, the intercept should be equal to zero and can be dropped.
alphas = np.arange(0, 20, .2)
ridge_r2 = []
lasso_r2 = []
for lambd in alphas:
    ridgeregr = linear_model.Ridge(alpha=lambd, fit_intercept=False) 
    ridgeregr.fit(X_train2, Y_train)
    print('\nR^2 for the Ridge regression:')
    print(ridgeregr.score(X_train2, Y_train))
    ridge_r2.append(ridgeregr.score(X_train2, Y_train))
    origparams = ridgeregr.coef_[0]
    print('\nParamter estimates for the Ridge Regression:')
    print(origparams)

    lassBig = linear_model.Lasso(alpha=lambd)
    lassBig.fit(X_train2, Y_train)
    print('\nR^2 for the Lasso Regression:')
    print(lassBig.score(X_train2, Y_train))
    lasso_r2.append(lassBig.score(X_train2, Y_train))
    newparams = np.append(lassBig.coef_, lassBig.intercept_)
    print('\nParamter estimates for the Ridge Regression model:')
    print(newparams)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/scipy/linalg/basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 6.863128803211895e-23 / 1.1102230246251565e-16
#   RuntimeWarning)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:20: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:477: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   positive)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/scipy/linalg/basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 3.66801327188232e-17 / 1.1102230246251565e-16
#   RuntimeWarning)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/scipy/linalg/basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 7.377185767681707e-17 / 1.1102230246251565e-16
#   RuntimeWarning)
# R^2 for the Ridge regression:
# 0.5739733101714712
#
# Paramter estimates for the Ridge Regression:
# [-4.29086594e-03 -7.58973864e-01  1.08645473e+01 -1.66258070e-03
#   1.18241472e-02 -4.44875119e-03  1.12674244e+02 -1.73035024e-01
#   6.03608634e-04]
#
# R^2 for the Lasso Regression:
# 0.5739444483155421
#
# Paramter estimates for the Ridge Regression model:
# [-2.06111494e-03 -7.58818422e-01  6.04810006e-02 -3.53546655e-03
#   9.26788633e-03 -3.79292001e-03  1.76197742e-01 -2.05761745e-04
#  -9.11532536e-07  1.20391468e+00]
#
# R^2 for the Ridge regression:
# 0.5739720657073142
#
# Paramter estimates for the Ridge Regression:
# [-5.20400477e-03 -7.58907697e-01  2.61232119e-01 -1.75860747e-03
#   1.24042767e-02 -4.38938859e-03 -2.42990757e-02  2.66141682e-03
#  -2.63711550e-05]
#
# R^2 for the Lasso Regression:
# 0.5312352331355782
#
# Paramter estimates for the Ridge Regression model:
# [ 0.00000000e+00 -5.48198136e-01  0.00000000e+00 -0.00000000e+00
#   0.00000000e+00 -0.00000000e+00  0.00000000e+00 -1.88233524e-04
#  -1.34452444e-07  2.01679367e+00]
#
# R^2 for the Ridge regression:
# 0.5739714114491172
#
# Paramter estimates for the Ridge Regression:
# [-4.91612718e-03 -7.58861985e-01  2.39539806e-01 -1.92859621e-03
#   1.21185219e-02 -4.33348116e-03 -2.23706157e-02  2.44006047e-03
#  -2.41771772e-05]
#
# R^2 for the Lasso Regression:
# 0.4038148555303922
#
# Paramter estimates for the Ridge Regression model:
# [ 0.00000000e+00 -3.36400437e-01  0.00000000e+00 -0.00000000e+00
#   0.00000000e+00 -0.00000000e+00  0.00000000e+00 -2.39783936e-04
#  -1.35165582e-06  3.75098548e+00]
#
# R^2 for the Ridge regression:
# 0.5739705549004197
#
# Paramter estimates for the Ridge Regression:
# [-4.67155198e-03 -7.58818173e-01  2.21171388e-01 -2.07350639e-03
#   1.18762075e-02 -4.28590071e-03 -2.06826735e-02  2.25249685e-03
#  -2.23186751e-05]
#
# R^2 for the Lasso Regression:
# 0.1914467410568793
#
# Paramter estimates for the Ridge Regression model:
# [ 0.00000000e+00 -1.24594058e-01  0.00000000e+00 -0.00000000e+00
#   0.00000000e+00 -0.00000000e+00  0.00000000e+00 -0.00000000e+00
#  -4.50868014e-06  4.51194787e+00]
#
# R^2 for the Ridge regression:
# 0.5739695981426511
#
# Paramter estimates for the Ridge Regression:
# [-4.46104932e-03 -7.58775857e-01  2.05414716e-01 -2.19868395e-03
#   1.16680736e-02 -4.24487227e-03 -1.92219648e-02  2.09158137e-03
#  -2.07243456e-05]
#
# R^2 for the Lasso Regression:
# 0.026834134749037727
#
# Paramter estimates for the Ridge Regression model:
# [ 0.00000000e+00 -0.00000000e+00  0.00000000e+00 -0.00000000e+00
#   0.00000000e+00 -0.00000000e+00  0.00000000e+00  0.00000000e+00
#  -5.42654555e-06  5.43071695e+00]
#
# R^2 for the Ridge regression:
# 0.5739686014514886
#
# Paramter estimates for the Ridge Regression:
# [-4.27783830e-03 -7.58734740e-01  1.91749284e-01 -2.30805622e-03
#   1.14873174e-02 -4.20909186e-03 -1.79503523e-02  1.95202108e-03
#  -1.93416477e-05]
#
# R^2 for the Lasso Regression:
# 0.026834134351719777
#
# Paramter estimates for the Ridge Regression model:
# [ 0.00000000e+00 -0.00000000e+00  0.00000000e+00 -0.00000000e+00
#   0.00000000e+00 -0.00000000e+00  0.00000000e+00  0.00000000e+00
#  -5.42632541e-06  5.43049680e+00]
#
# R^2 for the Ridge regression:
# 0.5739676005954599
#
# Paramter estimates for the Ridge Regression:
# [-4.11682564e-03 -7.58694598e-01  1.79784548e-01 -2.40457311e-03
#   1.13288291e-02 -4.17758006e-03 -1.68347579e-02  1.82983341e-03
#  -1.81310921e-05]
#
# R^2 for the Lasso Regression:
# 0.026834133866108337
#
# Paramter estimates for the Ridge Regression model:
# [ 0.00000000e+00 -0.00000000e+00  0.00000000e+00 -0.00000000e+00
#   0.00000000e+00 -0.00000000e+00  0.00000000e+00  0.00000000e+00
#  -5.42610527e-06  5.43027666e+00]
#
# R^2 for the Ridge regression:
# 0.5739666166341548
#
# Paramter estimates for the Ridge Regression:
# [-3.97411134e-03 -7.58655260e-01  1.69221576e-01 -2.49049337e-03
#   1.11886961e-02 -4.14958689e-03 -1.58486612e-02  1.72196704e-03
#  -1.70624349e-05]
#
# R^2 for the Lasso Regression:
# 0.0268341332922043
#
# Paramter estimates for the Ridge Regression model:
# [ 0.00000000e+00 -0.00000000e+00  0.00000000e+00 -0.00000000e+00
#   0.00000000e+00 -0.00000000e+00  0.00000000e+00  0.00000000e+00
#  -5.42588513e-06  5.43005651e+00]
#
# R^2 for the Ridge regression:
# 0.57396566164164
#
# Paramter estimates for the Ridge Regression:
# [-3.84665859e-03 -7.58616595e-01  1.59827638e-01 -2.56757583e-03
#   1.10638719e-02 -4.12452840e-03 -1.49709881e-02  1.62604532e-03
#  -1.61121236e-05]
#
# R^2 for the Lasso Regression:
# 0.026834132630007
#
# Paramter estimates for the Ridge Regression model:
# [ 0.00000000e+00 -0.00000000e+00  0.00000000e+00 -0.00000000e+00
#   0.00000000e+00 -0.00000000e+00  0.00000000e+00  0.00000000e+00
#  -5.42566499e-06  5.42983636e+00]
#
# R^2 for the Ridge regression:
# 0.573964742136581
#
# Paramter estimates for the Ridge Regression:
# [-3.73206749e-03 -7.58578495e-01  1.51418834e-01 -2.63721043e-03
#   1.09519487e-02 -4.10194309e-03 -1.41849072e-02  1.54018979e-03
#  -1.52615445e-05]
#
# R^2 for the Lasso Regression:
# 0.026834131879516998
#
# Paramter estimates for the Ridge Regression model:
# [ 0.00000000e+00 -0.00000000e+00  0.00000000e+00 -0.00000000e+00
#   0.00000000e+00 -0.00000000e+00  0.00000000e+00  0.00000000e+00
#  -5.42544485e-06  5.42961622e+00]
#
# R^2 for the Ridge regression:
# 0.5739638611811475
#
# Paramter estimates for the Ridge Regression:
# [-3.62841636e-03 -7.58540878e-01  1.43847914e-01 -2.70051016e-03
#   1.08509988e-02 -4.08146141e-03 -1.34768559e-02  1.46289616e-03
#  -1.44957924e-05]
#
# R^2 for the Lasso Regression:
# 0.026834131040733955
#
# Paramter estimates for the Ridge Regression model:
# [ 0.00000000e+00 -0.00000000e+00  0.00000000e+00 -0.00000000e+00
#   0.00000000e+00 -0.00000000e+00  0.00000000e+00  0.00000000e+00
#  -5.42522471e-06  5.42939607e+00]
#
# R^2 for the Ridge regression:
# 0.573963019689106
#
# Paramter estimates for the Ridge Regression:
# [-3.53414829e-03 -7.58503674e-01  1.36995584e-01 -2.75837673e-03
#   1.07594601e-02 -4.06278399e-03 -1.28358018e-02  1.39294563e-03
#  -1.38027912e-05]
#
# R^2 for the Lasso Regression:
# 0.026834130113657872
#
# Paramter estimates for the Ridge Regression model:
# [ 0.00000000e+00 -0.00000000e+00  0.00000000e+00 -0.00000000e+00
#   0.00000000e+00 -0.00000000e+00  0.00000000e+00  0.00000000e+00
#  -5.42500457e-06  5.42917592e+00]
#
# R^2 for the Ridge regression:
# 0.5739622172516232
#
# Paramter estimates for the Ridge Regression:
# [-3.44798854e-03 -7.58466829e-01  1.30764174e-01 -2.81154842e-03
#   1.06760537e-02 -4.04566569e-03 -1.22526886e-02  1.32934024e-03
#  -1.31726534e-05]
#
# R^2 for the Lasso Regression:
# 0.026834129098289083
#
# Paramter estimates for the Ridge Regression model:
# [ 0.00000000e+00 -0.00000000e+00  0.00000000e+00 -0.00000000e+00
#   0.00000000e+00 -0.00000000e+00  0.00000000e+00  0.00000000e+00
#  -5.42478443e-06  5.42895578e+00]
#
# R^2 for the Ridge regression:
# 0.5739614526633852
#
# Paramter estimates for the Ridge Regression:
# [-3.36888333e-03 -7.58430296e-01  1.25072946e-01 -2.86063554e-03
#   1.05997226e-02 -4.02990388e-03 -1.17200147e-02  1.27125501e-03
#  -1.25972053e-05]
#
# R^2 for the Lasso Regression:
# 0.026834127994627255
#
# Paramter estimates for the Ridge Regression model:
# [ 0.00000000e+00 -0.00000000e+00  0.00000000e+00 -0.00000000e+00
#   0.00000000e+00 -0.00000000e+00  0.00000000e+00  0.00000000e+00
#  -5.42456429e-06  5.42873563e+00]
#
# R^2 for the Ridge regression:
# 0.5739607242607907
#
# Paramter estimates for the Ridge Regression:
# [-3.29595400e-03 -7.58394036e-01  1.19854576e-01 -2.90614699e-03
#   1.05295852e-02 -4.01532959e-03 -1.12315161e-02  1.21800203e-03
#  -1.20696312e-05]
#
# R^2 for the Lasso Regression:
# 0.026834126802672383
#
# Paramter estimates for the Ridge Regression model:
# [ 0.00000000e+00 -0.00000000e+00  0.00000000e+00 -0.00000000e+00
#   0.00000000e+00 -0.00000000e+00  0.00000000e+00  0.00000000e+00
#  -5.42434415e-06  5.42851549e+00]
#
# R^2 for the Ridge regression:
# 0.5739600301398755
#
# Paramter estimates for the Ridge Regression:
# [-3.22846209e-03 -7.58358018e-01  1.15052487e-01 -2.94851047e-03
#   1.04649007e-02 -4.00180082e-03 -1.07819232e-02  1.16900314e-03
#  -1.15842033e-05]
#
# R^2 for the Lasso Regression:
# 0.02683412552242459
#
# Paramter estimates for the Ridge Regression model:
# [ 0.00000000e+00 -0.00000000e+00  0.00000000e+00 -0.00000000e+00
#   0.00000000e+00 -0.00000000e+00  0.00000000e+00  0.00000000e+00
#  -5.42412401e-06  5.42829534e+00]
#
# R^2 for the Ridge regression:
# 0.5739593682949715
#
# Paramter estimates for the Ridge Regression:
# [-3.16578238e-03 -7.58322213e-01  1.10618777e-01 -2.98808807e-03
#   1.04050418e-02 -3.98919734e-03 -1.03667702e-02  1.12376886e-03
#  -1.11360718e-05]
#
# R^2 for the Lasso Regression:
# 0.026834124153884083
#
# Paramter estimates for the Ridge Regression model:
# [ 0.00000000e+00 -0.00000000e+00  0.00000000e+00 -0.00000000e+00
#   0.00000000e+00 -0.00000000e+00  0.00000000e+00  0.00000000e+00
#  -5.42390387e-06  5.42807519e+00]
#
# R^2 for the Ridge regression:
# 0.5739587367083953
#
# Paramter estimates for the Ridge Regression:
# [-3.10738208e-03 -7.58286598e-01  1.06512626e-01 -3.02518837e-03
#   1.03494740e-02 -3.97741670e-03 -9.98224944e-03  1.08188204e-03
#  -1.07211040e-05]
#
# R^2 for the Lasso Regression:
# 0.026834122697050104
#
# Paramter estimates for the Ridge Regression model:
# [ 0.00000000e+00 -0.00000000e+00  0.00000000e+00 -0.00000000e+00
#   0.00000000e+00 -0.00000000e+00  0.00000000e+00 -0.00000000e+00
#  -5.42368373e-06  5.42785505e+00]
#
# R^2 for the Ridge regression:
# 0.5739581334046224
#
# Paramter estimates for the Ridge Regression:
# [-3.05280426e-03 -7.58251154e-01  1.02699026e-01 -3.06007599e-03
#   1.02977390e-02 -3.96637103e-03 -9.62509315e-03  1.04298495e-03
#  -1.03357558e-05]
#
# R^2 for the Lasso Regression:
# 0.02683412115192374
#
# Paramter estimates for the Ridge Regression model:
# [ 0.00000000e+00 -0.00000000e+00  0.00000000e+00 -0.00000000e+00
#   0.00000000e+00 -0.00000000e+00  0.00000000e+00 -0.00000000e+00
#  -5.42346359e-06  5.42763490e+00]
#
# R^2 for the Ridge regression:
# 0.5739575564847093
#
# Paramter estimates for the Ridge Regression:
# [-3.00165491e-03 -7.58215863e-01  9.91477896e-02 -3.09297915e-03
#   1.02494414e-02 -3.95598456e-03 -9.29248260e-03  1.00676909e-03
#  -9.97697073e-06]
#
# R^2 for the Lasso Regression:
# 0.0268341195185039
#
# Paramter estimates for the Ridge Regression model:
# [ 0.00000000e+00 -0.00000000e+00  0.00000000e+00 -0.00000000e+00
#   0.00000000e+00 -0.00000000e+00  0.00000000e+00 -0.00000000e+00
#  -5.42324345e-06  5.42741475e+00]
#
# R^2 for the Ridge regression:
# 0.5739570041443899
#
# Paramter estimates for the Ridge Regression:
# [-2.95359241e-03 -7.58180710e-01  9.58327436e-02 -3.12409570e-03
#   1.02042386e-02 -3.94619161e-03 -8.98197285e-03  9.72966987e-04
#  -9.64209898e-06]
#
# R^2 for the Lasso Regression:
# 0.026834117796791568
#
# Paramter estimates for the Ridge Regression model:
# [ 0.00000000e+00 -0.00000000e+00  0.00000000e+00 -0.00000000e+00
#   0.00000000e+00 -0.00000000e+00  0.00000000e+00 -0.00000000e+00
#  -5.42302331e-06  5.42719461e+00]
#
# R^2 for the Ridge regression:
# 0.5739564746834678
#
# Paramter estimates for the Ridge Regression:
# [-2.90831909e-03 -7.58145682e-01  9.27310830e-02 -3.15359803e-03
#   1.01618318e-02 -3.93693493e-03 -8.69143272e-03  9.41345598e-04
#  -9.32883167e-06]
#
# R^2 for the Lasso Regression:
# 0.026834115986785978
#
# Paramter estimates for the Ridge Regression model:
# [ 0.00000000e+00 -0.00000000e+00  0.00000000e+00 -0.00000000e+00
#   0.00000000e+00 -0.00000000e+00  0.00000000e+00 -0.00000000e+00
#  -5.42280317e-06  5.42697446e+00]
#
# R^2 for the Ridge regression:
# 0.5739559665093018
#
# Paramter estimates for the Ridge Regression:
# [-2.86557444e-03 -7.58110768e-01  8.98228487e-02 -3.18163701e-03
#   1.01219598e-02 -3.92816443e-03 -8.41899682e-03  9.11700951e-04
#  -9.03514803e-06]
#
# R^2 for the Lasso Regression:
# 0.02683411408848757
#
# Paramter estimates for the Ridge Regression model:
# [ 0.00000000e+00 -0.00000000e+00  0.00000000e+00 -0.00000000e+00
#   0.00000000e+00 -0.00000000e+00  0.00000000e+00 -0.00000000e+00
#  -5.42258303e-06  5.42675431e+00]
#
# R^2 for the Ridge regression:
# 0.5739554781355265
#
# Paramter estimates for the Ridge Regression:
# [-2.82512943e-03 -7.58075957e-01  8.70904947e-02 -3.20834530e-03
#   1.00843927e-02 -3.91983606e-03 -8.16302462e-03  8.83853737e-04
#  -8.75927162e-06]
#
# R^2 for the Lasso Regression:
# 0.026834112101896235
#
# Paramter estimates for the Ridge Regression model:
# [ 0.00000000e+00 -0.00000000e+00  0.00000000e+00 -0.00000000e+00
#   0.00000000e+00 -0.00000000e+00  0.00000000e+00 -0.00000000e+00
#  -5.42236289e-06  5.42653417e+00]
#
# R^2 for the Ridge regression:
# 0.573955008178948
#
# Paramter estimates for the Ridge Regression:
# [-2.78678194e-03 -7.58041242e-01  8.45185350e-02 -3.23383995e-03
#   1.00489279e-02 -3.91191096e-03 -7.92206808e-03  8.57645698e-04
#  -8.49963456e-06]
#
# R^2 for the Lasso Regression:
# 0.026834110027011967
#
# Paramter estimates for the Ridge Regression model:
# [ 0.00000000e+00 -0.00000000e+00  0.00000000e+00 -0.00000000e+00
#   0.00000000e+00 -0.00000000e+00  0.00000000e+00 -0.00000000e+00
#  -5.42214275e-06  5.42631402e+00]
#
# R^2 for the Ridge regression:
# 0.5739545553546429
#
# Paramter estimates for the Ridge Regression:
# [-2.75035289e-03 -7.58006613e-01  8.20932498e-02 -3.25822468e-03
#   1.00153856e-02 -3.90435470e-03 -7.69484396e-03  8.32936624e-04
#  -8.25484778e-06]
#
# R^2 for the Lasso Regression:
# 0.026834107863834555
#
# Paramter estimates for the Ridge Regression model:
# [ 0.00000000e+00 -0.00000000e+00  0.00000000e+00 -0.00000000e+00
#   0.00000000e+00 -0.00000000e+00  0.00000000e+00 -0.00000000e+00
#  -5.42192261e-06  5.42609387e+00]
#
# R^2 for the Ridge regression:
# 0.5739541184703663
#
# Paramter estimates for the Ridge Regression:
# [-2.71568304e-03 -7.57972064e-01  7.98024405e-02 -3.28159171e-03
#   9.98360614e-03 -3.89713664e-03 -7.48021113e-03  8.09601849e-04
#  -8.02367620e-06]
#
# R^2 for the Lasso Regression:
# 0.026834105612364437
#
# Paramter estimates for the Ridge Regression model:
# [ 0.00000000e+00 -0.00000000e+00  0.00000000e+00 -0.00000000e+00
#   0.00000000e+00 -0.00000000e+00  0.00000000e+00 -0.00000000e+00
#  -5.42170247e-06  5.42587373e+00]
#
# R^2 for the Ridge regression:
# 0.5739536964207455
#
# Paramter estimates for the Ridge Regression:
# [-2.68263037e-03 -7.57937589e-01  7.76352253e-02 -3.30402330e-03
#   9.95344698e-03 -3.89022949e-03 -7.27715157e-03  7.87530170e-04
#  -7.80501811e-06]
#
# R^2 for the Lasso Regression:
# 0.02683410327260105
#
# Paramter estimates for the Ridge Regression model:
# [ 0.00000000e+00 -0.00000000e+00  0.00000000e+00 -0.00000000e+00
#   0.00000000e+00 -0.00000000e+00  0.00000000e+00 -0.00000000e+00
#  -5.42148233e-06  5.42565358e+00]
#
# R^2 for the Ridge regression:
# 0.573953288180996
#
# Paramter estimates for the Ridge Regression:
# [-2.65106774e-03 -7.57903182e-01  7.55818651e-02 -3.32559306e-03
#   9.92478061e-03 -3.88360880e-03 -7.08475406e-03  7.66622055e-04
#  -7.59788745e-06]
#
# R^2 for the Lasso Regression:
# 0.026834100844545072
#
# Paramter estimates for the Ridge Regression model:
# [ 0.00000000e+00 -0.00000000e+00  0.00000000e+00 -0.00000000e+00
#   0.00000000e+00 -0.00000000e+00  0.00000000e+00 -0.00000000e+00
#  -5.42126220e-06  5.42543343e+00]
#
# R^2 for the Ridge regression:
# 0.5739528928011799
#
# Paramter estimates for the Ridge Regression:
# [-2.62088106e-03 -7.57868838e-01  7.36336182e-02 -3.34636709e-03
#   9.89749255e-03 -3.87725261e-03 -6.90220049e-03  7.46788166e-04
#  -7.40139914e-06]
#
# R^2 for the Lasso Regression:
# 0.026834098328196054
#
# Paramter estimates for the Ridge Regression model:
# [ 0.00000000e+00 -0.00000000e+00  0.00000000e+00 -0.00000000e+00
#   0.00000000e+00 -0.00000000e+00  0.00000000e+00 -0.00000000e+00
#  -5.42104206e-06  5.42521329e+00]
#
# R^2 for the Ridge regression:
# 0.573952509400462
#
# Paramter estimates for the Ridge Regression:
# [-2.59196760e-03 -7.57834553e-01  7.17826149e-02 -3.36640488e-03
#   9.87147975e-03 -3.87114119e-03 -6.72875436e-03  7.27948079e-04
#  -7.21475643e-06]
#
# R^2 for the Lasso Regression:
# 0.026834095723553997
#
# Paramter estimates for the Ridge Regression model:
# [ 0.00000000e+00 -0.00000000e+00  0.00000000e+00 -0.00000000e+00
#   0.00000000e+00 -0.00000000e+00  0.00000000e+00 -0.00000000e+00
#  -5.42082192e-06  5.42499314e+00]
#
# R^2 for the Ridge regression:
# 0.5739521371618856
#
# Paramter estimates for the Ridge Regression:
# [-2.56423466e-03 -7.57800322e-01  7.00217529e-02 -3.38576011e-03
#   9.84664921e-03 -3.86525671e-03 -6.56375091e-03  7.10029210e-04
#  -7.03724020e-06]
#
# R^2 for the Lasso Regression:
# 0.02683409303061912
#
# Paramter estimates for the Ridge Regression model:
# [ 0.00000000e+00 -0.00000000e+00  0.00000000e+00 -0.00000000e+00
#   0.00000000e+00 -0.00000000e+00  0.00000000e+00 -0.00000000e+00
#  -5.42060178e-06  5.42477299e+00]
#
# R^2 for the Ridge regression:
# 0.5739517753271582
#
# Paramter estimates for the Ridge Regression:
# [-2.53759832e-03 -7.57766142e-01  6.83446041e-02 -3.40448138e-03
#   9.82291675e-03 -3.85958302e-03 -6.40658846e-03  6.92965868e-04
#  -6.86819967e-06]
#
# R^2 for the Lasso Regression:
# 0.026834090249391093
#
# Paramter estimates for the Ridge Regression model:
# [ 0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#   0.00000000e+00 -0.00000000e+00  0.00000000e+00 -0.00000000e+00
#  -5.42038164e-06  5.42455285e+00]
#
# R^2 for the Ridge regression:
# 0.5739514231921252
#
# Paramter estimates for the Ridge Regression:
# [-2.51198248e-03 -7.57732010e-01  6.67453381e-02 -3.42261276e-03
#   9.80020603e-03 -3.85410550e-03 -6.25672121e-03  6.76698466e-04
#  -6.70704448e-06]
#
# R^2 for the Lasso Regression:
# 0.026834087379870256
#
# Paramter estimates for the Ridge Regression model:
# [ 0.0000000e+00 -0.0000000e+00 -0.0000000e+00 -0.0000000e+00
#   0.0000000e+00 -0.0000000e+00  0.0000000e+00 -0.0000000e+00
#  -5.4201615e-06  5.4243327e+00]
#
# R^2 for the Ridge regression:
# 0.5739510801023959
#
# Paramter estimates for the Ridge Regression:
# [-2.48731794e-03 -7.57697923e-01  6.52186534e-02 -3.44019434e-03
#   9.77844761e-03 -3.84881084e-03 -6.11365281e-03  6.61172824e-04
#  -6.55323790e-06]
#
# R^2 for the Lasso Regression:
# 0.026834084422056367
#
# Paramter estimates for the Ridge Regression model:
# [ 0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#   0.00000000e+00 -0.00000000e+00  0.00000000e+00 -0.00000000e+00
#  -5.41994136e-06  5.42411256e+00]
#
# R^2 for the Ridge regression:
# 0.5739507454493709
#
# Paramter estimates for the Ridge Regression:
# [-2.46354164e-03 -7.57663877e-01  6.37597190e-02 -3.45726263e-03
#   9.75757824e-03 -3.84368691e-03 -5.97693096e-03  6.46339571e-04
#  -6.40629080e-06]
#
# R^2 for the Lasso Regression:
# 0.02683408137594967
#
# Paramter estimates for the Ridge Regression model:
# [ 0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#   0.00000000e+00 -0.00000000e+00  0.00000000e+00 -0.00000000e+00
#  -5.41972122e-06  5.42389241e+00]
#
# R^2 for the Ridge regression:
# 0.5739504186665387
#
# Paramter estimates for the Ridge Regression:
# [-2.44059599e-03 -7.57629871e-01  6.23641231e-02 -3.47385099e-03
#   9.73754015e-03 -3.83872264e-03 -5.84614260e-03  6.32153619e-04
#  -6.26575649e-06]
#
# R^2 for the Lasso Regression:
# 0.02683407824154982
#
# Paramter estimates for the Ridge Regression model:
# [ 0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#   0.00000000e+00 -0.00000000e+00  0.00000000e+00 -0.00000000e+00
#  -5.41950108e-06  5.42367226e+00]
#
# R^2 for the Ridge regression:
# 0.5739500992262758
#
# Paramter estimates for the Ridge Regression:
# [-2.41842829e-03 -7.57595901e-01  6.10278296e-02 -3.48998992e-03
#   9.71828048e-03 -3.83390789e-03 -5.72090983e-03  6.18573721e-04
#  -6.13122633e-06]
#
# R^2 for the Lasso Regression:
# 0.026834075018857265
#
# Paramter estimates for the Ridge Regression model:
# [ 0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#   0.00000000e+00 -0.00000000e+00  0.00000000e+00 -0.00000000e+00
#  -5.41928094e-06  5.42345212e+00]
#
# R^2 for the Ridge regression:
# 0.5739497866365021
#
# Paramter estimates for the Ridge Regression:
# [-2.39699025e-03 -7.57561967e-01  5.97471371e-02 -3.50570740e-03
#   9.69975075e-03 -3.82923338e-03 -5.60088600e-03  6.05562049e-04
#  -6.00232557e-06]
#
# R^2 for the Lasso Regression:
# 0.02683407170787167
#
# Paramter estimates for the Ridge Regression model:
# [ 0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#   0.00000000e+00 -0.00000000e+00  0.00000000e+00 -0.00000000e+00
#  -5.41906080e-06  5.42323197e+00]
#
# R^2 for the Ridge regression:
# 0.5739494804381545
#
# Paramter estimates for the Ridge Regression:
# [-2.37623748e-03 -7.57528065e-01  5.85186468e-02 -3.52102914e-03
#   9.68190647e-03 -3.82469058e-03 -5.48575287e-03  5.93083869e-04
#  -5.87871009e-06]
#
# R^2 for the Lasso Regression:
# 0.02683406830859314
#
# Paramter estimates for the Ridge Regression model:
# [ 0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#   0.00000000e+00 -0.00000000e+00  0.00000000e+00 -0.00000000e+00
#  -5.41884066e-06  5.42301182e+00]
#
# R^2 for the Ridge regression:
# 0.5739491802023791
#
# Paramter estimates for the Ridge Regression:
# [-2.35612916e-03 -7.57494194e-01  5.73392310e-02 -3.53597877e-03
#   9.66470667e-03 -3.82027163e-03 -5.37521748e-03  5.81107215e-04
#  -5.76006320e-06]
#
# R^2 for the Lasso Regression:
# 0.02683406482102157
#
# Paramter estimates for the Ridge Regression model:
# [ 0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#   0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#  -5.41862052e-06  5.42279168e+00]
#
# R^2 for the Ridge regression:
# 0.5739488855283015
#
# Paramter estimates for the Ridge Regression:
# [-2.33662765e-03 -7.57460353e-01  5.62060068e-02 -3.55057810e-03
#   9.64811361e-03 -3.81596930e-03 -5.26900985e-03  5.69602625e-04
#  -5.64609303e-06]
#
# R^2 for the Lasso Regression:
# 0.026834061245157196
#
# Paramter estimates for the Ridge Regression model:
# [ 0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#   0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#  -5.41840038e-06  5.42257153e+00]
#
# R^2 for the Ridge regression:
# 0.5739485960409962
#
# Paramter estimates for the Ridge Regression:
# [-2.31769823e-03 -7.57426540e-01  5.51163136e-02 -3.56484722e-03
#   9.63209243e-03 -3.81177691e-03 -5.16688086e-03  5.58542908e-04
#  -5.53653020e-06]
# R^2 for the Lasso Regression:
# 0.026834057580999545
#
# Paramter estimates for the Ridge Regression model:
# [ 0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#   0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#  -5.41818024e-06  5.42235138e+00]
#
# R^2 for the Ridge regression:
# 0.57394831138912
#
# Paramter estimates for the Ridge Regression:
# [-2.29930876e-03 -7.57392753e-01  5.40676900e-02 -3.57880475e-03
#   9.61661090e-03 -3.80768828e-03 -5.06859988e-03  5.47902909e-04
#  -5.43112550e-06]
#
# R^2 for the Lasso Regression:
# 0.026834053828549195
#
# Paramter estimates for the Ridge Regression model:
# [ 0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#   0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#  -5.41796010e-06  5.42213124e+00]
#
# R^2 for the Ridge regression:
# 0.5739480312436422
#
# Paramter estimates for the Ridge Regression:
# [-2.28142950e-03 -7.57358992e-01  5.30578581e-02 -3.59246792e-03
#   9.60163920e-03 -3.80369770e-03 -4.97395363e-03  5.37659347e-04
#  -5.32964828e-06]
#
# R^2 for the Lasso Regression:
# 0.02683404998780603
#
# Paramter estimates for the Ridge Regression model:
# [ 0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#   0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#  -5.41773996e-06  5.42191109e+00]
#
# R^2 for the Ridge regression:
# 0.5739477552957141
#
# Paramter estimates for the Ridge Regression:
# [-2.26403286e-03 -7.57325254e-01  5.20847042e-02 -3.60585269e-03
#   9.58714964e-03 -3.79979985e-03 -4.88274408e-03  5.27790623e-04
#  -5.23188456e-06]
#
# R^2 for the Lasso Regression:
# 0.0268340460587696
#
# Paramter estimates for the Ridge Regression model:
# [ 0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#   0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#  -5.41751982e-06  5.42169094e+00]
#
# R^2 for the Ridge regression:
# 0.5739474832555265
#
# Paramter estimates for the Ridge Regression:
# [-2.24709322e-03 -7.57291540e-01  5.11462663e-02 -3.61897390e-03
#   9.57311654e-03 -3.79598981e-03 -4.79478747e-03  5.18276684e-04
#  -5.13763567e-06]
#
# R^2 for the Lasso Regression:
# 0.026834042041440465
#
# Paramter estimates for the Ridge Regression model:
# [ 0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#   0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#  -5.41729968e-06  5.42147080e+00]
#
# R^2 for the Ridge regression:
# 0.5739472148506701
#
# Paramter estimates for the Ridge Regression:
# [-2.23058677e-03 -7.57257847e-01  5.02407193e-02 -3.63184535e-03
#   9.55951598e-03 -3.79226300e-03 -4.70991284e-03  5.09098879e-04
#  -5.04671684e-06]
#
# R^2 for the Lasso Regression:
# 0.0268340379358184
#
# Paramter estimates for the Ridge Regression model:
# [ 0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#   0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#  -5.41707954e-06  5.42125065e+00]
#
# R^2 for the Ridge regression:
# 0.5739469498250577
#
# Paramter estimates for the Ridge Regression:
# [-2.21449131e-03 -7.57224176e-01  4.93663643e-02 -3.64447988e-03
#   9.54632572e-03 -3.78861516e-03 -4.62796104e-03  5.00239844e-04
#  -4.95895605e-06]
#
# R^2 for the Lasso Regression:
# 0.026834033741903185
#
# Paramter estimates for the Ridge Regression model:
# [ 0.0000000e+00 -0.0000000e+00 -0.0000000e+00 -0.0000000e+00
#   0.0000000e+00 -0.0000000e+00 -0.0000000e+00 -0.0000000e+00
#  -5.4168594e-06  5.4210305e+00]
#
# R^2 for the Ridge regression:
# 0.573946687937608
#
# Paramter estimates for the Ridge Regression:
# [-2.19878618e-03 -7.57190524e-01  4.85216171e-02 -3.65688947e-03
#   9.53352501e-03 -3.78504231e-03 -4.54878365e-03  4.91683388e-04
#  -4.87419290e-06]
#
# R^2 for the Lasso Regression:
# 0.026834029459695038
#
# Paramter estimates for the Ridge Regression model:
# [ 0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#   0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#  -5.41663926e-06  5.42081036e+00]
#
# R^2 for the Ridge regression:
# 0.5739464289613365
#
# Paramter estimates for the Ridge Regression:
# [-2.18345205e-03 -7.57156891e-01  4.77049992e-02 -3.66908529e-03
#   9.52109450e-03 -3.78154074e-03 -4.47224220e-03  4.83414403e-04
#  -4.79227770e-06]
#
# R^2 for the Lasso Regression:
# 0.02683402508919408
#
# Paramter estimates for the Ridge Regression model:
# [ 0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#   0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#  -5.41641912e-06  5.42059021e+00]
#
# R^2 for the Ridge regression:
# 0.5739461726821837
#
# Paramter estimates for the Ridge Regression:
# [-2.16847090e-03 -7.57123277e-01  4.69151285e-02 -3.68107780e-03
#   9.50901607e-03 -3.77810697e-03 -4.39820718e-03  4.75418763e-04
#  -4.71307052e-06]
#
# R^2 for the Lasso Regression:
# 0.02683402063040019
#
# Paramter estimates for the Ridge Regression model:
# [ 0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#   0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#  -5.41619898e-06  5.42037006e+00]
#
# R^2 for the Ridge regression:
# 0.5739459188983336
#
# Paramter estimates for the Ridge Regression:
# [-2.15382584e-03 -7.57089680e-01  4.61507127e-02 -3.69287675e-03
#   9.49727281e-03 -3.77473777e-03 -4.32655755e-03  4.67683261e-04
#  -4.63644050e-06]
#
# R^2 for the Lasso Regression:
# 0.02683401608331304
#
# Paramter estimates for the Ridge Regression model:
# [ 0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#   0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#  -5.41597885e-06  5.42014992e+00]
#
# R^2 for the Ridge regression:
# 0.5739456674191774
#
# Paramter estimates for the Ridge Regression:
# [-2.13950107e-03 -7.57056100e-01  4.54105407e-02 -3.70449132e-03
#   9.48584885e-03 -3.77143010e-03 -4.25717983e-03  4.60195521e-04
#  -4.56226504e-06]
#
# R^2 for the Lasso Regression:
# 0.026834011447933404
#
# Paramter estimates for the Ridge Regression model:
# [ 0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#   0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#  -5.41575871e-06  5.41992977e+00]
#
# R^2 for the Ridge regression:
# 0.5739454180647074
#
# Paramter estimates for the Ridge Regression:
# [-2.12548176e-03 -7.57022537e-01  4.46934776e-02 -3.71593007e-03
#   9.47472933e-03 -3.76818110e-03 -4.18996770e-03  4.52943942e-04
#  -4.49042922e-06]
#
# R^2 for the Lasso Regression:
# 0.026834006724260503
#
# Paramter estimates for the Ridge Regression model:
# [ 0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#   0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#  -5.41553857e-06  5.41970962e+00]
#
# R^2 for the Ridge regression:
# 0.5739451706647047
#
# Paramter estimates for the Ridge Regression:
# [-2.11175401e-03 -7.56988989e-01  4.39984579e-02 -3.72720107e-03
#   9.46390030e-03 -3.76498810e-03 -4.12482132e-03  4.45917636e-04
#  -4.42082516e-06]
#
# R^2 for the Lasso Regression:
# 0.026834001912294684
#
# Paramter estimates for the Ridge Regression model:
# [ 0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#   0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#  -5.41531843e-06  5.41948948e+00]
#
# R^2 for the Ridge regression:
# 0.5739449250581855
#
# Paramter estimates for the Ridge Regression:
# [-2.09830474e-03 -7.56955456e-01  4.33244808e-02 -3.73831187e-03
#   9.45334864e-03 -3.76184858e-03 -4.06164694e-03  4.39106375e-04
#  -4.35335154e-06]
#
# R^2 for the Lasso Regression:
# 0.026833997012035926
#
# Paramter estimates for the Ridge Regression model:
# [ 0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#   0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#  -5.41509829e-06  5.41926933e+00]
#
# R^2 for the Ridge regression:
# 0.5739446810926943
#
# Paramter estimates for the Ridge Regression:
# [-2.08512168e-03 -7.56921938e-01  4.26706050e-02 -3.74926960e-03
#   9.44306204e-03 -3.75876019e-03 -4.00035636e-03  4.32500539e-04
#  -4.28791305e-06]
#
# R^2 for the Lasso Regression:
# 0.026833992023484358
#
# Paramter estimates for the Ridge Regression model:
# [ 0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#   0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#  -5.41487815e-06  5.41904919e+00]
#
# R^2 for the Ridge regression:
# 0.5739444386238484
#
# Paramter estimates for the Ridge Regression:
# [-2.07219324e-03 -7.56888434e-01  4.20359447e-02 -3.76008095e-03
#   9.43302888e-03 -3.75572071e-03 -3.94086660e-03  4.26091075e-04
#  -4.22442001e-06]
#
# R^2 for the Lasso Regression:
# 0.02683398694663952
#
# Paramter estimates for the Ridge Regression model:
# [ 0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#   0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#  -5.41465801e-06  5.41882904e+00]
#
# R^2 for the Ridge regression:
# 0.5739441975147253
#
# Paramter estimates for the Ridge Regression:
# [-2.05950853e-03 -7.56854943e-01  4.14196652e-02 -3.77075223e-03
#   9.42323824e-03 -3.75272802e-03 -3.88309942e-03  4.19869452e-04
#  -4.16278790e-06]
#
# R^2 for the Lasso Regression:
# 0.026833981781502092
#
# Paramter estimates for the Ridge Regression model:
# [ 0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#   0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#  -5.41443787e-06  5.41860889e+00]
#
# R^2 for the Ridge regression:
# 0.5739439576355336
#
# Paramter estimates for the Ridge Regression:
# [-2.04705727e-03 -7.56821465e-01  4.08209798e-02 -3.78128939e-03
#   9.41367981e-03 -3.74978017e-03 -3.82698114e-03  4.13827631e-04
#  -4.10293707e-06]
#
# R^2 for the Lasso Regression:
# 0.026833976528071513
#
# Paramter estimates for the Ridge Regression model:
# [ 0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#   0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#  -5.41421773e-06  5.41838875e+00]
#
# R^2 for the Ridge regression:
# 0.5739437188629819
#
# Paramter estimates for the Ridge Regression:
# [-2.03482977e-03 -7.56788000e-01  4.02391456e-02 -3.79169804e-03
#   9.40434386e-03 -3.74687528e-03 -3.77244213e-03  4.07958018e-04
#  -4.04479229e-06]
#
# R^2 for the Lasso Regression:
# 0.026833971186347897
#
# Paramter estimates for the Ridge Regression model:
# [ 0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#   0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#  -5.41399759e-06  5.41816860e+00]
#
# R^2 for the Ridge regression:
# 0.573943481080076
#
# Paramter estimates for the Ridge Regression:
# [-2.02281687e-03 -7.56754548e-01  3.96734613e-02 -3.80198349e-03
#   9.39522121e-03 -3.74401160e-03 -3.71941670e-03  4.02253449e-04
#  -3.98828259e-06]
#
# R^2 for the Lasso Regression:
# 0.026833965756331683
#
# Paramter estimates for the Ridge Regression model:
# [ 0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#   0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#  -5.41377745e-06  5.41794845e+00]
#
# R^2 for the Ridge regression:
# 0.573943244175547
#
# Paramter estimates for the Ridge Regression:
# [-2.01100991e-03 -7.56721107e-01  3.91232638e-02 -3.81215075e-03
#   9.38630316e-03 -3.74118745e-03 -3.66784270e-03  3.96707144e-04
#  -3.93334080e-06]
#
# R^2 for the Lasso Regression:
# 0.0268339602380222
#
# Paramter estimates for the Ridge Regression model:
# [ 0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#   0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#  -5.41355731e-06  5.41772831e+00]
#
# R^2 for the Ridge regression:
# 0.5739430080436503
#
# Paramter estimates for the Ridge Regression:
# [-1.99940069e-03 -7.56687678e-01  3.85879259e-02 -3.82220456e-03
#   9.37758152e-03 -3.73840127e-03 -3.61766137e-03  3.91312694e-04
#  -3.87990343e-06]
#
# R^2 for the Lasso Regression:
# 0.02683395463141991
#
# Paramter estimates for the Ridge Regression model:
# [ 0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#   0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#  -5.41333717e-06  5.41750816e+00]
#
# R^2 for the Ridge regression:
# 0.5739427725837478
#
# Paramter estimates for the Ridge Regression:
# [-1.98798146e-03 -7.56654260e-01  3.80668538e-02 -3.83214941e-03
#   9.36904849e-03 -3.73565157e-03 -3.56881705e-03  3.86064031e-04
#  -3.82791035e-06]
#
# R^2 for the Lasso Regression:
# 0.026833948936524687
#
# Paramter estimates for the Ridge Regression model:
# [ 0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#   0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#  -5.41311703e-06  5.41728801e+00]
#
# R^2 for the Ridge regression:
# 0.5739425377000462
#
# Paramter estimates for the Ridge Regression:
# [-1.97674488e-03 -7.56620853e-01  3.75594848e-02 -3.84198956e-03
#   9.36069671e-03 -3.73293692e-03 -3.52125703e-03  3.80955403e-04
#  -3.77730461e-06]
#
# R^2 for the Lasso Regression:
# 0.026833943153336426
#
# Paramter estimates for the Ridge Regression model:
# [ 0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#   0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#  -5.41289689e-06  5.41706787e+00]
#
# R^2 for the Ridge regression:
# 0.5739423033013189
#
# Paramter estimates for the Ridge Regression:
# [-1.96568397e-03 -7.56587456e-01  3.70652857e-02 -3.85172903e-03
#   9.35251919e-03 -3.73025600e-03 -3.47493134e-03  3.75981362e-04
#  -3.72803219e-06]
#
# R^2 for the Lasso Regression:
# 0.02683393728185512
#
# Paramter estimates for the Ridge Regression model:
# [ 0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#   0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#  -5.41267675e-06  5.41684772e+00]
#
# R^2 for the Ridge regression:
# 0.5739420693006118
#
# Paramter estimates for the Ridge Regression:
# [-1.95479213e-03 -7.56554070e-01  3.65837503e-02 -3.86137165e-03
#   9.34450930e-03 -3.72760753e-03 -3.42979255e-03  3.71136734e-04
#  -3.68004187e-06]
#
# R^2 for the Lasso Regression:
# 0.026833931322081117
#
# Paramter estimates for the Ridge Regression model:
# [ 0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#   0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#  -5.41245661e-06  5.41662757e+00]
#
# R^2 for the Ridge regression:
# 0.57394183561502
#
# Paramter estimates for the Ridge Regression:
# [-1.94406307e-03 -7.56520694e-01  3.61143982e-02 -3.87092106e-03
#   9.33666075e-03 -3.72499030e-03 -3.38579564e-03  3.66416610e-04
#  -3.63328499e-06]
#
# R^2 for the Lasso Regression:
# 0.026833925274014184
#
# Paramter estimates for the Ridge Regression model:
# [ 0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#   0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#  -5.41223647e-06  5.41640743e+00]
#
# R^2 for the Ridge regression:
# 0.5739416021654342
#
# Paramter estimates for the Ridge Regression:
# [-1.93349085e-03 -7.56487327e-01  3.56567728e-02 -3.88038070e-03
#   9.32896756e-03 -3.72240317e-03 -3.34289781e-03  3.61816323e-04
#  -3.58771533e-06]
#
# R^2 for the Lasso Regression:
# 0.02683391913765409
#
# Paramter estimates for the Ridge Regression model:
# [ 0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#   0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#  -5.41201633e-06  5.41618728e+00]
#
# R^2 for the Ridge regression:
# 0.573941368876387
#
# Paramter estimates for the Ridge Regression:
# [-1.92306978e-03 -7.56453970e-01  3.52104403e-02 -3.88975386e-03
#   9.32142404e-03 -3.71984505e-03 -3.30105843e-03  3.57331439e-04
#  -3.54328896e-06]
#
# R^2 for the Lasso Regression:
# 0.02683391291300108
#
# Paramter estimates for the Ridge Regression model:
# [ 0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#   0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#  -5.41179619e-06  5.41596713e+00]
#
# R^2 for the Ridge regression:
# 0.5739411356757843
#
# Paramter estimates for the Ridge Regression:
# [-1.91279448e-03 -7.56420622e-01  3.47749879e-02 -3.89904366e-03
#   9.31402479e-03 -3.71731490e-03 -3.26023881e-03  3.52957741e-04
#  -3.49996410e-06]
#
# R^2 for the Lasso Regression:
# 0.026833906600055135
#
# Paramter estimates for the Ridge Regression model:
# [ 0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#   0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#  -5.41157605e-06  5.41574699e+00]
#
# R^2 for the Ridge regression:
# 0.5739409024947472
#
# Paramter estimates for the Ridge Regression:
# [-1.90265982e-03 -7.56387283e-01  3.43500226e-02 -3.90825306e-03
#   9.30676466e-03 -3.71481174e-03 -3.22040212e-03  3.48691211e-04
#  -3.45770095e-06]
#
# R^2 for the Lasso Regression:
# 0.02683390019881615
#
# Paramter estimates for the Ridge Regression model:
# [ 0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#   0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#  -5.41135591e-06  5.41552684e+00]
#
# R^2 for the Ridge regression:
# 0.5739406692674365
#
# Paramter estimates for the Ridge Regression:
# [-1.89266089e-03 -7.56353953e-01  3.39351703e-02 -3.91738490e-03
#   9.29963874e-03 -3.71233463e-03 -3.18151329e-03  3.44528026e-04
#  -3.41646162e-06]
#
# R^2 for the Lasso Regression:
# 0.026833893709284348
#
# Paramter estimates for the Ridge Regression model:
# [ 0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#   0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#  -5.41113577e-06  5.41530669e+00]
#
# R^2 for the Ridge regression:
# 0.5739404359309147
#
# Paramter estimates for the Ridge Regression:
# [-1.88279305e-03 -7.56320632e-01  3.35300743e-02 -3.92644187e-03
#   9.29264237e-03 -3.70988266e-03 -3.14353891e-03  3.40464541e-04
#  -3.37621002e-06]
#
# R^2 for the Lasso Regression:
# 0.026833887131459618
#
# Paramter estimates for the Ridge Regression model:
# [ 0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#   0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#  -5.41091563e-06  5.41508655e+00]
#
# R^2 for the Ridge regression:
# 0.5739402024249344
#
# Paramter estimates for the Ridge Regression:
# [-1.87305186e-03 -7.56287319e-01  3.31343945e-02 -3.93542654e-03
#   9.28577109e-03 -3.70745499e-03 -3.10644711e-03  3.36497280e-04
#  -3.33691170e-06]
#
# R^2 for the Lasso Regression:
# 0.026833880465341853
#
# Paramter estimates for the Ridge Regression model:
# [ 0.0000000e+00 -0.0000000e+00 -0.0000000e+00 -0.0000000e+00
#   0.0000000e+00 -0.0000000e+00 -0.0000000e+00 -0.0000000e+00
#  -5.4106955e-06  5.4148664e+00]
#
# R^2 for the Ridge regression:
# 0.5739399686918405
#
# Paramter estimates for the Ridge Regression:
# [-1.86343307e-03 -7.56254015e-01  3.27478066e-02 -3.94434137e-03
#   9.27902065e-03 -3.70505080e-03 -3.07020747e-03  3.32622929e-04
#  -3.29853382e-06]
#
# R^2 for the Lasso Regression:
# 0.02683387371093138
#
# Paramter estimates for the Ridge Regression model:
# [ 0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#   0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#  -5.41047536e-06  5.41464626e+00]
#
# R^2 for the Ridge regression:
# 0.5739397346764279
#
# Paramter estimates for the Ridge Regression:
# [-1.85393263e-03 -7.56220718e-01  3.23700008e-02 -3.95318870e-03
#   9.27238698e-03 -3.70266932e-03 -3.03479098e-03  3.28838320e-04
#  -3.26104503e-06]
#
# R^2 for the Lasso Regression:
# 0.02683386686822764
#
# Paramter estimates for the Ridge Regression model:
# [ 0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#   0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#  -5.41025522e-06  5.41442611e+00]
#
# R^2 for the Ridge regression:
# 0.5739395003258101
#
# Paramter estimates for the Ridge Regression:
# [-1.84454668e-03 -7.56187429e-01  3.20006813e-02 -3.96197076e-03
#   9.26586623e-03 -3.70030980e-03 -3.00016993e-03  3.25140433e-04
#  -3.22441537e-06]
#
# R^2 for the Lasso Regression:
# 0.02683385993723109
#
# Paramter estimates for the Ridge Regression model:
# [ 0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#   0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#  -5.41003508e-06  5.41420596e+00]
#
# R^2 for the Ridge regression:
# 0.5739392655893041
#
# Paramter estimates for the Ridge Regression:
# [-1.83527153e-03 -7.56154148e-01  3.16395655e-02 -3.97068970e-03
#   9.25945468e-03 -3.69797152e-03 -2.96631781e-03  3.21526378e-04
#  -3.18861624e-06]
#
# R^2 for the Lasso Regression:
# 0.026833852917941606
#
# Paramter estimates for the Ridge Regression model:
# [ 0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#   0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#  -5.40981494e-06  5.41398582e+00]
#
# R^2 for the Ridge regression:
# 0.573939030418295
#
# Paramter estimates for the Ridge Regression:
# [-1.82610365e-03 -7.56120875e-01  3.12863832e-02 -3.97934754e-03
#   9.25314878e-03 -3.69565382e-03 -2.93320929e-03  3.17993393e-04
#  -3.15362025e-06]
#
# R^2 for the Lasso Regression:
# 0.026833845810359188
#
# Paramter estimates for the Ridge Regression model:
# [ 0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#   0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#  -5.40959480e-06  5.41376567e+00]
#
# R^2 for the Ridge regression:
# 0.5739387947661914
#
# Paramter estimates for the Ridge Regression:
# [-1.81703965e-03 -7.56087609e-01  3.09408758e-02 -3.98794626e-03
#   9.24694517e-03 -3.69335605e-03 -2.90082018e-03  3.14538837e-04
#  -3.11940125e-06]
#
# R^2 for the Lasso Regression:
# 0.02683383861448374
#
# Paramter estimates for the Ridge Regression model:
# [ 0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#   0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#  -5.40937466e-06  5.41354552e+00]
#
# R^2 for the Ridge regression:
# 0.5739385585882478
#
# Paramter estimates for the Ridge Regression:
# [-1.80807630e-03 -7.56054350e-01  3.06027960e-02 -3.99648771e-03
#   9.24084058e-03 -3.69107757e-03 -2.86912726e-03  3.11160180e-04
#  -3.08593419e-06]
#
# R^2 for the Lasso Regression:
# 0.02683383133031525
#
# Paramter estimates for the Ridge Regression model:
# [ 0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#   0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#  -5.40915452e-06  5.41332538e+00]
#
# R^2 for the Ridge regression:
# 0.5739383218415339
#
# Paramter estimates for the Ridge Regression:
# [-1.79921051e-03 -7.56021098e-01  3.02719068e-02 -4.00497369e-03
#   9.23483192e-03 -3.68881780e-03 -2.83810834e-03  3.07855003e-04
#  -3.05319508e-06]
#
# R^2 for the Lasso Regression:
# 0.02683382395785383
#
# Paramter estimates for the Ridge Regression model:
# [ 0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#   0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#  -5.40893438e-06  5.41310523e+00]
#
# R^2 for the Ridge regression:
# 0.5739380844848234
#
# Paramter estimates for the Ridge Regression:
# [-1.79043931e-03 -7.55987854e-01  2.99479815e-02 -4.01340592e-03
#   9.22891622e-03 -3.68657617e-03 -2.80774216e-03  3.04620987e-04
#  -3.02116095e-06]
#
# R^2 for the Lasso Regression:
# 0.0268338164970997
#
# Paramter estimates for the Ridge Regression model:
# [ 0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#   0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#  -5.40871424e-06  5.41288508e+00]
#
# R^2 for the Ridge regression:
# 0.5739378464785104
#
# Paramter estimates for the Ridge Regression:
# [-1.78175986e-03 -7.55954616e-01  2.96308025e-02 -4.02178604e-03
#   9.22309063e-03 -3.68435213e-03 -2.77800834e-03  3.01455909e-04
#  -2.98980979e-06]
#
# R^2 for the Lasso Regression:
# 0.02683380894805254
# Paramter estimates for the Ridge Regression model:
# [ 0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#   0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#  -5.40849410e-06  5.41266494e+00]
#
# R^2 for the Ridge regression:
# 0.5739376077845273
#
# Paramter estimates for the Ridge Regression:
# [-1.77316943e-03 -7.55921385e-01  2.93201613e-02 -4.03011562e-03
#   9.21735240e-03 -3.68214515e-03 -2.74888733e-03  2.98357637e-04
#  -2.95912048e-06]
#
# R^2 for the Lasso Regression:
# 0.026833801310712332
#
# Paramter estimates for the Ridge Regression model:
# [ 0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#   0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#  -5.40827396e-06  5.41244479e+00]
#
# R^2 for the Ridge regression:
# 0.5739373683662887
#
# Paramter estimates for the Ridge Regression:
# [-1.76466541e-03 -7.55888161e-01  2.90158579e-02 -4.03839618e-03
#   9.21169893e-03 -3.67995474e-03 -2.72036039e-03  2.95324129e-04
#  -2.92907277e-06]
#
# R^2 for the Lasso Regression:
# 0.026833793585079087
#
# Paramter estimates for the Ridge Regression model:
# [ 0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#   0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#  -5.40805382e-06  5.41222464e+00]
#
# R^2 for the Ridge regression:
# 0.5739371281886116
#
# Paramter estimates for the Ridge Regression:
# [-1.75624528e-03 -7.55854943e-01  2.87177005e-02 -4.04662917e-03
#   9.20612770e-03 -3.67778041e-03 -2.69240955e-03  2.92353423e-04
#  -2.89964724e-06]
#
# R^2 for the Lasso Regression:
# 0.026833785771153137
#
# Paramter estimates for the Ridge Regression model:
# [ 0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#   0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#  -5.40783368e-06  5.41200450e+00]
#
# R^2 for the Ridge regression:
# 0.5739368872176358
#
# Paramter estimates for the Ridge Regression:
# [-1.74790665e-03 -7.55821732e-01  2.84255048e-02 -4.05481598e-03
#   9.20063629e-03 -3.67562169e-03 -2.66501751e-03  2.89443636e-04
#  -2.87082522e-06]
#
# R^2 for the Lasso Regression:
# 0.026833777868933928
#
# Paramter estimates for the Ridge Regression model:
# [ 0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#   0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#  -5.40761354e-06  5.41178435e+00]
#
# R^2 for the Ridge regression:
# 0.5739366454207977
#
# Paramter estimates for the Ridge Regression:
# [-1.73964718e-03 -7.55788527e-01  2.81390937e-02 -4.06295795e-03
#   9.19522238e-03 -3.67347816e-03 -2.63816770e-03  2.86592959e-04
#  -2.84258880e-06]
#
# R^2 for the Lasso Regression:
# 0.02683376987842212
#
# Paramter estimates for the Ridge Regression model:
# [ 0.0000000e+00 -0.0000000e+00 -0.0000000e+00 -0.0000000e+00
#   0.0000000e+00 -0.0000000e+00 -0.0000000e+00 -0.0000000e+00
#  -5.4073934e-06  5.4115642e+00]
#
# R^2 for the Ridge regression:
# 0.573936402766745
#
# Paramter estimates for the Ridge Regression:
# [-1.73146467e-03 -7.55755328e-01  2.78582974e-02 -4.07105637e-03
#   9.18988374e-03 -3.67134936e-03 -2.61184420e-03  2.83799655e-04
#  -2.81492077e-06]
#
# R^2 for the Lasso Regression:
# 0.026833761799617162
#
# Paramter estimates for the Ridge Regression model:
# [ 0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#   0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#  -5.40717326e-06  5.41134406e+00]
#
# R^2 for the Ridge regression:
# 0.5739361592252846
#
# Paramter estimates for the Ridge Regression:
# [-1.72335697e-03 -7.55722136e-01  2.75829524e-02 -4.07911247e-03
#   9.18461824e-03 -3.66923491e-03 -2.58603168e-03  2.81062053e-04
#  -2.78780459e-06]
#
# R^2 for the Lasso Regression:
# 0.026833753632519493
#
# Paramter estimates for the Ridge Regression model:
# [ 0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#   0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#  -5.40695312e-06  5.41112391e+00]
#
# R^2 for the Ridge regression:
# 0.5739359147673229
#
# Paramter estimates for the Ridge Regression:
# [-1.71532203e-03 -7.55688949e-01  2.73129014e-02 -4.08712743e-03
#   9.17942380e-03 -3.66713440e-03 -2.56071540e-03  2.78378548e-04
#  -2.76122433e-06]
#
# R^2 for the Lasso Regression:
# 0.02683374537712868
#
# Paramter estimates for the Ridge Regression model:
# [ 0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#   0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#  -5.40673298e-06  5.41090376e+00]
#
# R^2 for the Ridge regression:
# 0.5739356693648561
#
# Paramter estimates for the Ridge Regression:
# [-1.70735787e-03 -7.55655768e-01  2.70479935e-02 -4.09510241e-03
#   9.17429846e-03 -3.66504745e-03 -2.53588122e-03  2.75747596e-04
#  -2.73516470e-06]
#
# R^2 for the Lasso Regression:
# 0.026833737033444716
#
# Paramter estimates for the Ridge Regression model:
# [ 0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#   0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#  -5.40651284e-06  5.41068362e+00]
#
# R^2 for the Ridge regression:
# 0.5739354229908566
#
# Paramter estimates for the Ridge Regression:
# [-1.69946258e-03 -7.55622594e-01  2.67880831e-02 -4.10303850e-03
#   9.16924030e-03 -3.66297369e-03 -2.51151549e-03  2.73167708e-04
#  -2.70961097e-06]
#
# R^2 for the Lasso Regression:
# 0.026833728601467932
#
# Paramter estimates for the Ridge Regression model:
# [ 0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#   0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#  -5.40629270e-06  5.41046347e+00]
#
# R^2 for the Ridge regression:
# 0.5739351756193039
#
# Paramter estimates for the Ridge Regression:
# [-1.69163434e-03 -7.55589425e-01  2.65330302e-02 -4.11093676e-03
#   9.16424749e-03 -3.66091278e-03 -2.48760509e-03  2.70637455e-04
#  -2.68454897e-06]
#
# R^2 for the Lasso Regression:
# 0.026833720081198335
#
# Paramter estimates for the Ridge Regression model:
# [ 0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#   0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#  -5.40607256e-06  5.41024333e+00]
#
# R^2 for the Ridge regression:
# 0.5739349272250596
#
# Paramter estimates for the Ridge Regression:
# [-1.68387138e-03 -7.55556262e-01  2.62826999e-02 -4.11879820e-03
#   9.15931826e-03 -3.65886437e-03 -2.46413736e-03  2.68155457e-04
#  -2.65996502e-06]
#
# R^2 for the Lasso Regression:
# 0.02683371147263569
#
# Paramter estimates for the Ridge Regression model:
# [ 0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#   0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#  -5.40585242e-06  5.41002318e+00]
#
# R^2 for the Ridge regression:
# 0.5739346777839243
#
# Paramter estimates for the Ridge Regression:
# [-1.67617200e-03 -7.55523104e-01  2.60369624e-02 -4.12662383e-03
#   9.15445091e-03 -3.65682814e-03 -2.44110015e-03  2.65720388e-04
#  -2.63584600e-06]
#
# R^2 for the Lasso Regression:
# 0.02683370277578023
#
# Paramter estimates for the Ridge Regression model:
# [ 0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#   0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#  -5.40563229e-06  5.40980303e+00]

# %%
print(ridge_r2)
print(lasso_r2)
print(alphas)
# Out:
# [0.5739733101714712, 0.5739720657073142, 0.5739714114491172, 0.5739705549004197, 0.5739695981426511, 0.5739686014514886, 0.5739676005954599, 0.5739666166341548, 0.57396566164164, 0.573964742136581, 0.5739638611811475, 0.573963019689106, 0.5739622172516232, 0.5739614526633852, 0.5739607242607907, 0.5739600301398755, 0.5739593682949715, 0.5739587367083953, 0.5739581334046224, 0.5739575564847093, 0.5739570041443899, 0.5739564746834678, 0.5739559665093018, 0.5739554781355265, 0.573955008178948, 0.5739545553546429, 0.5739541184703663, 0.5739536964207455, 0.573953288180996, 0.5739528928011799, 0.573952509400462, 0.5739521371618856, 0.5739517753271582, 0.5739514231921252, 0.5739510801023959, 0.5739507454493709, 0.5739504186665387, 0.5739500992262758, 0.5739497866365021, 0.5739494804381545, 0.5739491802023791, 0.5739488855283015, 0.5739485960409962, 0.57394831138912, 0.5739480312436422, 0.5739477552957141, 0.5739474832555265, 0.5739472148506701, 0.5739469498250577, 0.573946687937608, 0.5739464289613365, 0.5739461726821837, 0.5739459188983336, 0.5739456674191774, 0.5739454180647074, 0.5739451706647047, 0.5739449250581855, 0.5739446810926943, 0.5739444386238484, 0.5739441975147253, 0.5739439576355336, 0.5739437188629819, 0.573943481080076, 0.573943244175547, 0.5739430080436503, 0.5739427725837478, 0.5739425377000462, 0.5739423033013189, 0.5739420693006118, 0.57394183561502, 0.5739416021654342, 0.573941368876387, 0.5739411356757843, 0.5739409024947472, 0.5739406692674365, 0.5739404359309147, 0.5739402024249344, 0.5739399686918405, 0.5739397346764279, 0.5739395003258101, 0.5739392655893041, 0.573939030418295, 0.5739387947661914, 0.5739385585882478, 0.5739383218415339, 0.5739380844848234, 0.5739378464785104, 0.5739376077845273, 0.5739373683662887, 0.5739371281886116, 0.5739368872176358, 0.5739366454207977, 0.573936402766745, 0.5739361592252846, 0.5739359147673229, 0.5739356693648561, 0.5739354229908566, 0.5739351756193039, 0.5739349272250596, 0.5739346777839243]
# [0.5739444483155421, 0.5312352331355782, 0.4038148555303922, 0.1914467410568793, 0.026834134749037727, 0.026834134351719777, 0.026834133866108337, 0.0268341332922043, 0.026834132630007, 0.026834131879516998, 0.026834131040733955, 0.026834130113657872, 0.026834129098289083, 0.026834127994627255, 0.026834126802672383, 0.02683412552242459, 0.026834124153884083, 0.026834122697050104, 0.02683412115192374, 0.0268341195185039, 0.026834117796791568, 0.026834115986785978, 0.02683411408848757, 0.026834112101896235, 0.026834110027011967, 0.026834107863834555, 0.026834105612364437, 0.02683410327260105, 0.026834100844545072, 0.026834098328196054, 0.026834095723553997, 0.02683409303061912, 0.026834090249391093, 0.026834087379870256, 0.026834084422056367, 0.02683408137594967, 0.02683407824154982, 0.026834075018857265, 0.02683407170787167, 0.02683406830859314, 0.02683406482102157, 0.026834061245157196, 0.026834057580999545, 0.026834053828549195, 0.02683404998780603, 0.0268340460587696, 0.026834042041440465, 0.0268340379358184, 0.026834033741903185, 0.026834029459695038, 0.02683402508919408, 0.02683402063040019, 0.02683401608331304, 0.026834011447933404, 0.026834006724260503, 0.026834001912294684, 0.026833997012035926, 0.026833992023484358, 0.02683398694663952, 0.026833981781502092, 0.026833976528071513, 0.026833971186347897, 0.026833965756331683, 0.0268339602380222, 0.02683395463141991, 0.026833948936524687, 0.026833943153336426, 0.02683393728185512, 0.026833931322081117, 0.026833925274014184, 0.02683391913765409, 0.02683391291300108, 0.026833906600055135, 0.02683390019881615, 0.026833893709284348, 0.026833887131459618, 0.026833880465341853, 0.02683387371093138, 0.02683386686822764, 0.02683385993723109, 0.026833852917941606, 0.026833845810359188, 0.02683383861448374, 0.02683383133031525, 0.02683382395785383, 0.0268338164970997, 0.02683380894805254, 0.026833801310712332, 0.026833793585079087, 0.026833785771153137, 0.026833777868933928, 0.02683376987842212, 0.026833761799617162, 0.026833753632519493, 0.02683374537712868, 0.026833737033444716, 0.026833728601467932, 0.026833720081198335, 0.02683371147263569, 0.02683370277578023]
# [ 0.   0.2  0.4  0.6  0.8  1.   1.2  1.4  1.6  1.8  2.   2.2  2.4  2.6
#   2.8  3.   3.2  3.4  3.6  3.8  4.   4.2  4.4  4.6  4.8  5.   5.2  5.4
#   5.6  5.8  6.   6.2  6.4  6.6  6.8  7.   7.2  7.4  7.6  7.8  8.   8.2
#   8.4  8.6  8.8  9.   9.2  9.4  9.6  9.8 10.  10.2 10.4 10.6 10.8 11.
#  11.2 11.4 11.6 11.8 12.  12.2 12.4 12.6 12.8 13.  13.2 13.4 13.6 13.8
#  14.  14.2 14.4 14.6 14.8 15.  15.2 15.4 15.6 15.8 16.  16.2 16.4 16.6
#  16.8 17.  17.2 17.4 17.6 17.8 18.  18.2 18.4 18.6 18.8 19.  19.2 19.4
#  19.6 19.8]

# %%
plt.plot(alphas, ridge_r2)
plt.plot(alphas, lasso_r2)
plt.title("Ridge vs Lasso Regression")
plt.xlabel('Lamdas')
plt.ylabel('R^2 values')
plt.legend(['Ridge','Lasso'])
plt.show()
